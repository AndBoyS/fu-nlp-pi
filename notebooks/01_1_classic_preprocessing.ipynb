# %% [markdown]
# # Базовая обработка текста
#
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * https://www.nltk.org/api/nltk.html
# * https://pymorphy2.readthedocs.io/en/stable/
# * https://docs.python.org/3/library/re.html
# * https://regex101.com/

# %% [markdown]
# ## Задачи для совместного разбора

# %%
import re
import subprocess
from collections import defaultdict
from pathlib import Path

import nltk
import nltk.stem
import pandas as pd
import pymorphy2
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

nltk.download('stopwords')
repo_dir = Path(subprocess.check_output(["git", "rev-parse", "--show-toplevel"]).decode().strip())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anvbakhmatov\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# 1. Найдите все суммы (число плюс валюта), которые упоминаются в данном тексте. Выведите результат в виде списка кортежей из двух элементов (число, валюта)

# %%
text = """During my trip to Europe, I exchanged $10.50 for €20,00 at the currency exchange booth.
With ¥5000, I bought some souvenirs from a local market.
Later, I treated myself to a delicious meal at a restaurant, which cost me £15,99.
Finally, I converted 100₹ into the local currency to buy a traditional Indian artwork."""

# %%
patt = re.compile(r"([$€£¥₹]?)(\d+[.,]?\d+)([$€£¥₹]?)")
result = patt.findall(text)
[(c1 or c2, v) for c1, v, c2 in result]
# Out:
# [('$', '10.50'), ('€', '20,00'), ('¥', '5000'), ('£', '15,99'), ('₹', '100')]

# %% [markdown]
# 2\. Выясните, встречается ли в представленном фрагменте текста тавтология.

# %%
text = """Вода - это жидкость, которая имеет свойство быть водой.
Она состоит из молекул, которые образуют воду.
Вода, будучи водой, обладает свойствами, характерными для воды.
Ее молекулы, составляющие воду, образуют воду, которая является водой.
Таким образом, вода, будучи водой, является водой."""

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = word_tokenize(text.lower())
words[:5]
# Out:
# ['вода', '-', 'это', 'жидкость', ',']

# %%
# text.split()

# %%
tokenizer = RegexpTokenizer(r"\w+")
words = tokenizer.tokenize(text.lower())
words[:5]
# Out:
# ['вода', 'это', 'жидкость', 'которая', 'имеет']

# %%
stemmer = nltk.stem.SnowballStemmer("russian")
stemmed = pd.Series([stemmer.stem(w) for w in words])
stemmed.value_counts()

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
lemmatized = pd.Series([morph.parse(w)[0].normal_form for w in words])
lemmatized.value_counts()
# Out:
# вода           12
# который         3
# быть            3
# являться        2
# свойство        2
# она             2
# молекула        2
# образовать      2
# характерный     1
# такой           1
# составлять      1
# для             1
# из              1
# обладать        1
# это             1
# состоять        1
# иметь           1
# жидкость        1
# образ           1
# dtype: int64

# %% [markdown]
# ## Задачи для самостоятельного решения

# %% [markdown]
# <p class="task" id="1"></p>
#
# 1\. Исследуйте, какие формы слова "кот" или "кошка" встречаются в текстах из файла `moya-semia/Лучше кошки зверя нет 2.csv`. Сгруппируйте найденные слова по начальной форме и представьте результата в виде словаря, где ключом является начальная форма слова, а значением - список форм этого слова, которые встретились в тексте. Примеры подходящих слов: "котейки", "кошечка", "котик" и т.д.

# %%
df = pd.read_csv(repo_dir / r'data\moya-semia\Лучше кошки зверя нет 2.csv', header=None)

texts = df[1].tolist()
text = ' '.join(texts)

words_to_ignore = stopwords.words('russian')

tokenizer = RegexpTokenizer(r"\w+")
words = tokenizer.tokenize(text.lower())
words = set([word for word in words if word not in words_to_ignore])
words
# Out:
# {'пропадала',
#  'проволоку',
#  'конкурентами',
#  'котлетки',
#  'перевыполнила',
#  'пердержкой',
#  'обижаюсь',
#  'спасал',
#  'тех',
#  'отгонял',
#  'лирическое',
#  'раздаются',
#  'чеков',
#  'выслушав',
#  'маячком',
#  'отстой',
#  'охотятся',
#  'халяву',
#  'позвонков',
#  'балдеют',
#  'запретила',
#  'представьте',
#  '150',
#  'ударила',
#  'старту',
#  'подлетаю',
#  'возьмутсявозьмите',
#  'тычась',
#  'привередливые',
#  'лизину',
#  'троцким',
#  'рассказывабт',
#  'отклонений',
#  'обиженных',
#  'ужинает',
#  'рассказывай',
#  'упорно',
#  'пораньше',
#  'упавшего',
#  'нахождению',
#  'гимнастический',
#  'субботу',
#  'начищай',
#  'выложил',
#  'развлекать',
#  'обиженный',
#  'костюме',
#  'покричала',
#  'точная',
#  'мозга',
#  'некоторую',
#  'трапезу',
#  'пододеяльники',
#  'ледяной',
#  'копченую',
#  'открывала',
#  'выборе',
#  'показывать',
#  'задавила',
#  'стул',
#  'плавниками',
#  'помета',
#  'дунька',
#  'обедают',
#  'завтрака',
#  'выпозли',
#  'больной',
#  'полных',
#  'наглядное',
#  'ангор',
#  'нoвая',
#  'прикидывает',
#  'выражением',
#  'осторожная',
#  'разводить',
#  'кольца',
#  'длительное',
#  'выходили',
#  'витамины',
#  'озирался',
#  'везут',
#  'фыркнул',
#  'сараями',
#  'гладили',
#  'погромыхивала',
#  'знакомо',
#  'клубком',
#  'продаётся',
#  'психи',
#  'кончится',
#  'жует',
#  'стволу',
#  'наркозе',
#  'покрытия',
#  'придурку',
#  'подходить',
#  'прибежит',
#  'кофию',
#  'кушать',
#  'харчем',
#  'предприняла',
#  'помрет',
#  'дальнюю',
#  'изумленно',
#  'предложения',
#  'принадлежности',
#  'резинке',
#  'страхов',
#  'чистого',
#  'вливала',
#  'укрепляется',
#  'кличке',
#  'уборку',
#  'детективно',
#  'пусти',
#  'коллег',
#  'ослика',
#  'важная',
#  'хвостатыми',
#  'приезжают',
#  'везешь',
#  'приставайте',
#  'метит',
#  'постоянных',
#  'требуются',
#  'безропотно',
#  'даль',
#  'орёт',
#  'выезжают',
#  'форум',
#  'длинноногий',
#  'ревизор',
#  'мячиками',
#  'застряли',
#  'родителей',
#  'верите',
#  'возвращаемся',
#  'горькими',
#  'поклон',
#  'торшеру',
#  'трудитесь',
#  'прибежал',
#  'обезопасить',
#  'сбегать',
#  'округлился',
#  'участкам',
#  'считывают',
#  'задохлик',
#  'заводчица',
#  'помнят',
#  'сбиты',
#  'отчаянно',
#  'чет',
#  'шлялась',
#  'разодран',
#  'тоскливо',
#  'перья',
#  'побежит',
#  'феде',
#  'подарил',
#  'поел',
#  'тосковать',
#  'осваивали',
#  'приемлет',
#  'нисколько',
#  'одели',
#  'открыта',
#  'отодвинут',
#  'кафе',
#  'скуку',
#  'бонусов',
#  'деловому',
#  'обломав',
#  'преодолеть',
#  'открывая',
#  'ветра',
#  'котейшество',
#  'рейсшину',
#  '09',
#  'устало',
#  'сезар',
#  'проявлял',
#  'дальняк',
#  'паре',
#  'сманил',
#  'негодяйка',
#  'поводком',
#  'робко',
#  'считать',
#  'стесняясь',
#  'дворняжки',
#  'можете',
#  'профилактические',
#  'удружила',
#  'обосновался',
#  'вокзалам',
#  'полюбоваться',
#  'сыра',
#  'душа',
#  'шипела',
#  'питомец',
#  'квартирах',
#  'дюже',
#  'ваз',
#  'остальным',
#  'сцену',
#  'оценив',
#  'дрессировке',
#  'вертелась',
#  'достатке',
#  'беспредела',
#  'вытурить',
#  'сияют',
#  'мать',
#  'чувства',
#  'профессионально',
#  'шлея',
#  'поплелся',
#  'ведра',
#  'котишки',
#  'задали',
#  'подратый',
#  'привалило',
#  'сядет',
#  'вареное',
#  'рвала',
#  'категорическое',
#  'настроению',
#  'неохотно',
#  'пускаем',
#  'простынь',
#  'попец',
#  'стонал',
#  'молодого',
#  'пластик',
#  'выразительно',
#  'отпор',
#  'прибавил',
#  'короб',
#  'зоозащитных',
#  'вцепилось',
#  'вывезли',
#  'встретиться',
#  'худого',
#  'расстегивать',
#  'расслаблялась',
#  'отошел',
#  'едуа',
#  'кроватке',
#  'иначе',
#  'неположенном',
#  'шкребет',
#  'добираться',
#  'зашёл',
#  'икал',
#  'копать',
#  'толстяка',
#  'молочница',
#  'рисовую',
#  'лопатой',
#  'окончена',
#  'йоню',
#  'ландшафтного',
#  'вкусняху',
#  'бойлерной',
#  'блюдет',
#  'затем',
#  'мгновенно',
#  'позвоночника',
#  'неволе',
#  'лил',
#  'лошадку',
#  'живописной',
#  'методе',
#  'исполняются',
#  'газетой',
#  'тасканием',
#  'бич',
#  'топить',
#  'действительностью',
#  'задвигает',
#  'пищат',
#  'сдуло',
#  'холодильником',
#  'кусачек',
#  'ландшафтом',
#  'ненормальная',
#  'пёрышко',
#  'болезненная',
#  'ввалился',
#  'высовывает',
#  'завались',
#  'густоту',
#  'крыльях',
#  'определенный',
#  'обучили',
#  'котовместимость',
#  'прежнему',
#  'высокая',
#  'отдельный',
#  'подогрела',
#  'свирепый',
#  'аристократа',
#  'дергает',
#  'летит',
#  'уживались',
#  'котейшества',
#  'болотной',
#  'отнеслось',
#  'брызгаете',
#  'трчат',
#  'перестал',
#  'дыру',
#  'переборчива',
#  'потребуется',
#  'отгрызли',
#  'пальцев',
#  'породистая',
#  'пьедестале',
#  'поглаживаний',
#  'наедятся',
#  'действия',
#  'тишине',
#  'виноградинку',
#  'членам',
#  'занимаются',
#  'игнорировала',
#  'одобряет',
#  'занимают',
#  'морозный',
#  'коленками',
#  'пятницы',
#  'проститутом',
#  'машине',
#  'варя',
#  'продолжала',
#  'ме',
#  'фолдов',
#  'подчиняться',
#  'существует',
#  'окрасом',
#  'регулярно',
#  'погрызть',
#  'шелохнулась',
#  'вычесывала',
#  'субстанцию',
#  'гирюхи',
#  'пары',
#  'вырастет',
#  'таблички',
#  'обжора',
#  'шелковистой',
#  'картона',
#  'шуганула',
#  'интересный',
#  'причесывать',
#  'поверхность',
#  'заказов',
#  'бессердечные',
#  'поживиться',
#  'применял',
#  'уловив',
#  'силком',
#  'сползаю',
#  'месячную',
#  'усыплению',
#  'вздыхали',
#  'молодежи',
#  'закрытия',
#  'определили',
#  'моих',
#  'кафель',
#  'полуживые',
#  'https',
#  'офигеваю',
#  'поближе',
#  'кавардак',
#  'тоскуют',
#  'постоянного',
#  'загоняем',
#  'ощущался',
#  'закрылась',
#  'подруги',
#  'порвет',
#  'подкрепление',
#  'кошатник',
#  'существа',
#  'распоряжаться',
#  'деру',
#  'замечания',
#  'идее',
#  'хомяка',
#  'ковролин',
#  'укромные',
#  'красавца',
#  'любим',
#  'подружилась',
#  'смириться',
#  'отойди',
#  'отчинил',
#  'расстоянии',
#  'доедать',
#  'кустиками',
#  'сохранности',
#  'сетях',
#  'отбежал',
#  'стукалась',
#  'засиживаюсь',
#  'успокоительные',
#  'продолжаю',
#  'бандит',
#  'сходку',
#  'обгрызть',
#  'поделился',
#  'диктовать',
#  'напряжно',
#  'уберусь',
#  'включили',
#  'лап',
#  'таскания',
#  'мытье',
#  'крепких',
#  'беседовали',
#  'трусоватый',
#  'стеллаж',
#  'отгоняет',
#  'устремится',
#  'эльфийская',
#  'ветрахветрах',
#  'баки',
#  'разомлевшая',
#  'пхе',
#  'перевернут',
#  'здоровое',
#  'посадил',
#  'указываю',
#  'шмидточкачтоб',
#  'почитала',
#  'кличка',
#  'специальный',
#  'терроризирует',
#  'изящные',
#  'училась',
#  'публика',
#  'заставляет',
#  'стенки',
#  'обретал',
#  'страшные',
#  'равнодушно',
#  'эмоционально',
#  'котейки',
#  'придут',
#  'приходящего',
#  'подточишь',
#  'сшибание',
#  'облизывает',
#  'оовольная',
#  'просил',
#  'биполярным',
#  'паникую',
#  'убить',
#  'чувством',
#  'тележку',
#  'меры',
#  'мальвинкой',
#  'шло',
#  'единоличница',
#  'возглас',
#  'побрили',
#  'сибирская',
#  'повторила',
#  'телепатией',
#  'моржа',
#  'опечаток',
#  'пришёл',
#  'вскакивать',
#  'псинки',
#  'окрестностям',
#  'посматривают',
#  'кормом',
#  'полое',
#  'месить',
#  'попало',
#  'дрель',
#  'разгонится',
#  'шутку',
#  'тайских',
#  'загадочное',
#  'трубочка',
#  'одобрил',
#  'бушлат',
#  'покойного',
#  'привыкать',
#  'неправильное',
#  'влипают',
#  'мони',
#  'цветок',
#  'приходящей',
#  'дается',
#  'пятый',
#  'дробить',
#  'голодающее',
#  'проснулась',
#  'стояли',
#  'крокодила',
#  'завистливая',
#  'родственника',
#  'пластыри',
#  'естессссно',
#  'дрелью',
#  'бояться',
#  'валерию',
#  'приюты',
#  'налопаться',
#  'колыбельных',
#  'кухню',
#  'ржем',
#  'обошлось',
#  'другу',
#  'выпрямлялась',
#  'признаю',
#  'масштаб',
#  'дорогого',
#  'поддерживать',
#  'ораву',
#  'черный',
#  'многообещающий',
#  'ловила',
#  'ушках',
#  'подняла',
#  'наподдает',
#  'серванта',
#  'знатная',
#  'газированнаявы',
#  'мимики',
#  'разбежался',
#  'йогуртом',
#  'гулен',
#  'потруднее',
#  'племянницей',
#  'долгожданных',
#  'недобор',
#  'альпинист',
#  'матильдой',
#  'чихаю',
#  'приземлился',
#  'съело',
#  'обсирается',
#  'сдирает',
#  'никакая',
#  'полчаса',
#  'дырами',
#  'разбежаться',
#  'детскую',
#  'чавкал',
#  'извалялась',
#  'разделываю',
#  'привечаю',
#  'хозяйкой',
#  'хруст',
#  'лялечку',
#  'погонялись',
#  'семейства',
#  'восходящему',
#  'впечатлений',
#  'проходит',
#  'одуванчик',
#  'холодея',
#  'цветущая',
#  'веночком',
#  'ставили',
#  'добры',
#  'комнатам',
#  'количестве',
#  'любдей',
#  'зрительные',
#  'шепнуть',
#  'банные',
#  'рыженька',
#  'живо',
#  'отказали',
#  'релаксирующим',
#  'маруськой',
#  'мишкиной',
#  'диканьки',
#  'доросла',
#  'глазками',
#  'привёз',
#  'золотые',
#  'различаете',
#  'вытрясти',
#  'фред',
#  'ад',
#  'нараспашку',
#  'додержать',
#  'аванс',
#  'удостоверится',
#  'голубоглазые',
#  'оказались',
#  'блокноты',
#  'заскучала',
#  'ощущениям',
#  'вышла',
#  'держащих',
#  'куртке',
#  'запихнули',
#  'лопать',
#  'драк',
#  'признакам',
#  'твердый',
#  'вовлечены',
#  'припасла',
#  'полежу',
#  'расти',
#  'петель',
#  'класс',
#  'сгрызенного',
#  'определенному',
#  'отойдет',
#  'видать',
#  'гладит',
#  'форумах',
#  'катает',
#  'колесе',
#  'связанного',
#  'заготовленный',
#  'мобильнике',
#  'негативном',
#  'углы',
#  'заставляю',
#  'заломленный',
#  'мявкнул',
#  'отловила',
#  'рамой',
#  'смазывается',
#  'скажи',
#  'различие',
#  'лизнуть',
#  'столешницу',
#  'новогодним',
#  'металлическая',
#  'снимет',
#  'претензией',
#  'ровесники',
#  'останетесь',
#  'оставит',
#  'подпишусь',
#  'округлила',
#  'воротит',
#  'ветке',
#  'терпимо',
#  'беспечные',
#  'котята',
#  'беззубый',
#  'голосам',
#  'фиксировал',
#  'отложенную',
#  'укусит',
#  'команда',
#  'демонстративно',
#  'фильмы',
#  'эмилю',
#  'мочи',
#  'вытягивала',
#  'обхватить',
#  'встретила',
#  'искусственный',
#  'владелец',
#  'смешивать',
#  'околопорожному',
#  'аси',
#  'мечтайте',
#  'травим',
#  'любили',
#  'носику',
#  'связываюсь',
#  'заманить',
#  'маркус',
#  'снята',
#  'дачу',
#  'кровь',
#  'мооооу',
#  'конструкция',
#  'слушаются',
#  'выпустите',
#  'выкручивается',
#  'отдавала',
#  'собачью',
#  'белым',
#  'пособирали',
#  'сезона',
#  'простыл',
#  'преувеличениях',
#  'непередаваемое',
#  'мамо',
#  'превратностях',
#  'временем',
#  'обшипит',
#  'психующее',
#  'рекомендовал',
#  'наутро',
#  'неожиданно',
#  'проформы',
#  'всемирной',
#  'наивная',
#  'отдыхали',
#  'интересно',
#  'защитника',
#  'пристроен',
#  'насчёт',
#  'мущщин',
#  'прижатые',
#  'дубак',
#  'забежала',
#  'отловленных',
#  'котеньку',
#  'здоровый',
#  'сибиряком',
#  'поменялся',
#  'фонарики',
#  'продуманные',
#  'короткий',
#  'порожек',
#  'поспит',
#  'самортизировала',
#  'уродства',
#  'облегченный',
#  'забраться',
#  'суток',
#  'потискала',
#  'страшной',
#  'канитель',
#  'ладонь',
#  'крутившие',
#  'машину',
#  'братцев',
#  'приметила',
#  'потоммила',
#  'моль',
#  'долечим',
#  'ваську',
#  'собачки',
#  'ловец',
#  'вылижет',
#  'антресолях',
#  'странные',
#  'ярого',
#  'балконную',
#  'хомяком',
#  'случившегося',
#  'зарыть',
#  'любимые',
#  'сахарницы',
#  'измочаленная',
#  'дела',
#  'салата',
#  'чудовища',
#  'отвыкает',
#  'решать',
#  'собачонкой',
#  'чопич',
#  'пуховик',
#  'загоняюсь',
#  'обнюхивала',
#  'тааам',
#  'животик',
#  'четкий',
#  'грязных',
#  'засыпает',
#  'отсутствует',
#  'просматриваю',
#  'отчаяния',
#  'ясна',
#  'муркал',
#  'отправляет',
#  'красавчик',
#  'солнечную',
#  'неэффективно',
#  'острая',
#  'мишку',
#  'дождаться',
#  'возьмете',
#  'персиковый',
#  'поперлась',
#  'пышного',
#  'жареную',
#  'вытянутых',
#  'красавица',
#  'сижу',
#  'впрок',
#  'кинескопом',
#  'ломтика',
#  'зооволонтёров',
#  'булку',
#  'оставив',
#  'затолкала',
#  'шок',
#  'моргать',
#  'сущий',
#  'захотели',
#  'застряла',
#  'падения',
#  'грёб',
#  'перевернешься',
#  'орущего',
#  'стушевалась',
#  'переводе',
#  'бульончик',
#  'визжал',
#  'комплекции',
#  'выслушать',
#  'израненное',
#  'кудрявого',
#  'ересь',
#  'разведчица',
#  'тепле',
#  'подробности',
#  'отмоется',
#  'коня',
#  'воз',
#  'профилактики',
#  'передать',
#  'изменить',
#  'совместно',
#  'избить',
#  'метет',
#  'орёшь',
#  'дери',
#  'зацепятся',
#  'приятели',
#  'бабы',
#  'обернулась',
#  'чесал',
#  'лапах',
#  'порушит',
#  'крабовую',
#  'натяжную',
#  'салат',
#  'взобраться',
#  'подобрыш',
#  'звонил',
#  'хорошего',
#  'канючить',
#  'украшать',
#  'ферму',
#  'хозяйские',
#  'посматривает',
#  'мундире',
#  'камушком',
#  'удостаивается',
#  'стуле',
#  'издевайтесь',
#  'перерывами',
#  'собрала',
#  'попита',
#  'понедельника',
#  'думает',
#  'подцепил',
#  'востро',
#  'колоться',
#  'эустомы',
#  'холод',
#  'перевернула',
#  'нелюдимый',
#  'приставать',
#  'поисками',
#  'шуршания',
#  'пакетики',
#  'молнией',
#  'ругалась',
#  'разбавит',
#  'псом',
#  'крыску',
#  'бесился',
#  'теплое',
#  'выстригла',
#  'попозже',
#  'покатилась',
#  'драл',
#  'п',
#  'передней',
#  'лесовинказдоровенный',
#  'пробегает',
#  'сссать',
#  'варежки',
#  'смыкаясь',
#  'котяка',
#  'законопатила',
#  'рубец',
#  'парковке',
#  'пошагав',
#  'мирные',
#  'белочки',
#  'первых',
#  'слопали',
#  'густая',
#  'схлопотал',
#  'встречной',
#  'дразнилка',
#  'улетел',
#  'знакомой',
#  'упорная',
#  'брезгует',
#  'кушай',
#  'идеально',
#  'признаваться',
#  'просушку',
#  'стану',
#  'сильные',
#  'быстром',
#  'отлегло',
#  'бдительности',
#  'размеру',
#  'разворачиваюсь',
#  'точил',
#  'покладистый',
#  'груз',
#  'растащены',
#  'огородите',
#  'дебил',
#  'отъезжаем',
#  'раздался',
#  'жесты',
#  'пожалела',
#  'репертуара',
#  'противоположной',
#  'олухи',
#  'задрав',
#  'грецкие',
#  'местами',
#  'домики',
#  'баррикады',
#  'манеры',
#  'советую',
#  'лежать',
#  'вдарятся',
#  'филю',
#  'варить',
#  'света',
#  'закапывает',
#  'свежак',
#  'стерилизацию',
#  'полетали',
#  'дорогое',
#  'объяснением',
#  'двум',
#  'нарезанные',
#  'хлорофитум',
#  'знакомое',
#  'лапушка',
#  'намучаетесь',
#  'изучить',
#  'разной',
#  'отвести',
#  'кипяток',
#  'бонусом',
#  'пониманиемдевушки',
#  'курса',
#  'лысинка',
#  'метисы',
#  'караульный',
#  'семьи',
#  'отдать',
#  'сбросить',
#  'крутился',
#  'умирал',
#  'поразилонаучилась',
#  'кошака',
#  'ограничиваю',
#  'принесёт',
#  'котодевочек',
#  'окружении',
#  'восстановились',
#  'муська',
#  'цапнул',
#  'шестой',
#  'вырезка',
#  'опрокидывать',
#  'цель',
#  'цветка',
#  'разгребает',
#  'касей',
#  'сдана',
#  'держим',
#  'года',
#  'поля',
#  'прошлым',
#  'спил',
#  'перепадает',
#  'подложу',
#  'дневной',
#  'чайную',
#  'подслеповатые',
#  'красив',
#  '05',
#  'фаянсовые',
#  'бродячая',
#  'перепугалась',
#  'засохшую',
#  'выбрать',
#  ...}

# %%
morph = pymorphy2.MorphAnalyzer()
lemmatized_to_original = defaultdict(list)

for word in words:
    lemm_word = morph.parse(word)[0].normal_form
    lemmatized_to_original[lemm_word].append(word)

# %%
[
 (lemm_word, els) for lemm_word, els in lemmatized_to_original.items()
 if 'кот' in lemm_word or 'кош' in lemm_word
]
# Out:
# [('котлетка', ['котлетки', 'котлетку']),
#  ('некоторый',
#   ['некоторую', 'некоторых', 'некоторые', 'некоторое', 'некоторым']),
#  ('котейшество', ['котейшество', 'котейшества']),
#  ('котишка', ['котишки', 'котишка']),
#  ('котовместимость', ['котовместимость']),
#  ('кошатник',
#   ['кошатник',
#    'кошатникам',
#    'кошатнике',
#    'кошатники',
#    'кошатником',
#    'кошатника']),
#  ('котейка',
#   ['котейки', 'котеек', 'котейке', 'котейку', 'котейка', 'котейками']),
#  ('котёнок',
#   ['котята',
#    'котенка',
#    'котят',
#    'котятам',
#    'котёнком',
#    'котёнку',
#    'котенком',
#    'котёнок',
#    'котятами',
#    'котенок',
#    'котёнке',
#    'котёнка',
#    'котенку']),
#  ('котенёк', ['котеньку', 'котеньке', 'котеньки', 'котенек', 'котенька']),
#  ('котяк', ['котяка', 'котяки']),
#  ('кошак', ['кошака', 'кошак', 'кошакам', 'кошаки', 'кошаками', 'кошаков']),
#  ('котодевочка', ['котодевочек']),
#  ('котофей', ['котофей', 'котофеи', 'котофея', 'котофеям', 'котофеев']),
#  ('которебёнок', ['которебенку', 'которебенок', 'которебенка']),
#  ('кот',
#   ['коту',
#    'кот',
#    'котов',
#    'котом',
#    'котам',
#    'котами',
#    'коты',
#    'котах',
#    'коте',
#    'кота']),
#  ('котяточка', ['котяточек']),
#  ('кошачий',
#   ['кошачьему',
#    'кошачьи',
#    'кошачьей',
#    'кошачью',
#    'кошачий',
#    'кошачьих',
#    'кошачьем',
#    'кошачьими',
#    'кошачье',
#    'кошачьим',
#    'кошачья',
#    'кошачьего']),
#  ('кото', ['кото']),
#  ('кошмарный', ['кошмарное']),
#  ('скотинка', ['скотинка', 'скотинки']),
#  ('кошка',
#   ['кошкою',
#    'кошек',
#    'кошками',
#    'кошкой',
#    'кошке',
#    'кошка',
#    'кошку',
#    'кошкам',
#    'кошки']),
#  ('котёночек',
#   ['котяткам', 'котятки', 'котеночку', 'котёночка', 'котяток', 'котёночком']),
#  ('коть', ['коти', 'котю']),
#  ('кошковладелец',
#   ['кошковладельца',
#    'кошковладельцы',
#    'кошковладельцу',
#    'кошковладельцам',
#    'кошковладельцев']),
#  ('котеечка', ['котеечке', 'котеечка']),
#  ('окот', ['окот', 'окотом']),
#  ('недайкот', ['недайкоты']),
#  ('котоморда', ['котоморды', 'котоморд']),
#  ('котиковмой', ['котиковмоя']),
#  ('пощекотать', ['пощекотала']),
#  ('кошатникамия', ['кошатникамия']),
#  ('кошечка', ['кошечку', 'кошечкой', 'кошечки', 'кошечка', 'кошечке']),
#  ('который',
#   ['который',
#    'которой',
#    'которому',
#    'которым',
#    'которую',
#    'которое',
#    'которая',
#    'которые',
#    'которого',
#    'которых',
#    'котором',
#    'которыми']),
#  ('кошкин',
#   ['кошкиной',
#    'кошкиным',
#    'кошкин',
#    'кошкина',
#    'кошкины',
#    'кошкину',
#    'кошкиных',
#    'кошкиного']),
#  ('кошонка', ['кошонка']),
#  ('кошенька', ['кошеньку']),
#  ('котёнкалюд', ['котёнкалюда']),
#  ('муркотяк', ['муркотяки']),
#  ('антикошка', ['антикошкой', 'антикошка', 'антикошками', 'антикошки']),
#  ('котомать', ['котомать', 'котоматерью']),
#  ('котовладелец', ['котовладельцам']),
#  ('короткошерстность', ['короткошерстности']),
#  ('котик',
#   ['котик',
#    'котики',
#    'котиков',
#    'котика',
#    'котиком',
#    'котиками',
#    'котикам',
#    'котику']),
#  ('щекотание', ['щекотания']),
#  ('кошара', ['кошара', 'кошарой']),
#  ('котико', ['котико']),
#  ('облокотиться', ['облокотилась', 'облокотился']),
#  ('котлета', ['котлеты', 'котлету']),
#  ('котосессия', ['котосессии']),
#  ('котана', ['котану']),
#  ('котокафе', ['котокафе']),
#  ('двукотажный', ['двукотажная']),
#  ('кошатина', ['кошатину', 'кошатина', 'кошатины']),
#  ('главкот', ['главкота']),
#  ('котодевушка', ['котодевушка']),
#  ('котячий',
#   ['котячью',
#    'котячья',
#    'котячьего',
#    'котячьи',
#    'котячьим',
#    'котячьем',
#    'котячьей']),
#  ('роскошь', ['роскоши', 'роскошь']),
#  ('кошководовый', ['кошководов']),
#  ('кошкуда', ['кошкуда']),
#  ('скоттиша', ['скоттиш']),
#  ('котярый', ['котяра', 'котярой']),
#  ('котомиска', ['котомиски']),
#  ('котослонёнок', ['котослоненок']),
#  ('окошко', ['окошко', 'окошку', 'окошке', 'окошки', 'окошка']),
#  ('короткошёрстный',
#   ['короткошерстный',
#    'короткошерстные',
#    'короткошёрстная',
#    'короткошерстная']),
#  ('кошатница', ['кошатница', 'кошатницей']),
#  ('котька', ['котька']),
#  ('кошечий', ['кошеча']),
#  ('котинька', ['котиньке', 'котиньки']),
#  ('роскошный', ['роскошную', 'роскошный']),
#  ('кошкопровод', ['кошкопровод']),
#  ('кош', ['коши', 'кошу', 'коша']),
#  ('кошь', ['кошь']),
#  ('скотобаза', ['скотобазу']),
#  ('котячуя', ['котячую']),
#  ('котовский', ['котовские']),
#  ('котёл', ['котла']),
#  ('стеночкукот', ['стеночкукоты']),
#  ('божечкикошечка', ['божечкикошечки']),
#  ('котина', ['котина']),
#  ('локоть', ['локтей', 'локоть', 'локтем', 'локти', 'локтя']),
#  ('кошачить', ['кошачим']),
#  ('некошачий', ['некошачьих']),
#  ('ангелочеккотёнок', ['ангелочеккотенок']),
#  ('мягкотелый', ['мягкотелая']),
#  ('антикошачий', ['антикошачью']),
#  ('котий', ['котьему']),
#  ('щекотать', ['щекотать']),
#  ('кошенек', ['кошеньки', 'кошенька']),
#  ('котовый', ['котовая']),
#  ('укотерил', ['укотерил']),
#  ('безкотовий', ['безкотовья']),
#  ('котра', ['котрой']),
#  ('котище', ['котище']),
#  ('кошкино', ['кошкино', 'кошкином']),
#  ('окотиться', ['окотится', 'окотилась', 'окотиться']),
#  ('подлокотник', ['подлокотники', 'подлокотнике']),
#  ('кошколовкий', ['кошколовкой']),
#  ('трикотажный', ['трикотажная']),
#  ('кошелёк', ['кошелек', 'кошельку']),
#  ('скотина', ['скотина']),
#  ('переборкошка', ['переборкошки']),
#  ('котэ', ['котэ']),
#  ('котыжич', ['котыжич']),
#  ('коший', ['кошьим']),
#  ('котиться', ['котилась']),
#  ('окошечко', ['окошечко']),
#  ('кошачьм', ['кошачьм']),
#  ('котобанда', ['котобанда']),
#  ('котятина', ['котятины']),
#  ('котота', ['котота']),
#  ('кошколовкойд', ['кошколовкойда']),
#  ('котовь', ['котови']),
#  ('бойкот', ['бойкот']),
#  ('котея', ['котей']),
#  ('антикошкамид', ['антикошкамида']),
#  ('кошилёд', ['кошильде']),
#  ('котогвардия', ['котогвардия']),
#  ('котовладелтец', ['котовладелтцев']),
#  ('котодитё', ['котодитё']),
#  ('cкотов', ['cкотов']),
#  ('котофеевич', ['котофеевич']),
#  ('кошенция', ['кошенция']),
#  ('закошмаренный', ['закошмаренный']),
#  ('скотч', ['скотчем', 'скотч']),
#  ('котить', ['котя']),
#  ('котин', ['котиного']),
#  ('скоточеловек', ['скотолюдей']),
#  ('скотейка', ['скотейка']),
#  ('кошарик', ['кошарик']),
#  ('котопсячий', ['котопсячья']),
#  ('котоловкий', ['котоловки']),
#  ('кошандра', ['кошандрой']),
#  ('котодверь', ['котодвери']),
#  ('щекотёнок', ['щекотят'])]

# %% [markdown]
# <p class="task" id="2"></p>
#
# 2\. Получите и выведите на экран набор имён питомцев, упомянутых в текстах из файла `moya-semia/Лучше кошки зверя нет 2.csv`. Для простоты считайте, что имя питомца начинается с заглавной буквы и стоит не в начале предложения.

# %% [markdown]
# <p class="task" id="3"></p>
#
# 3\. Вычислите среднюю длину сообщения (в количестве предложений) в различных темах форума газеты "Моя Семья" (каждый файл из каталога `data/moya-semia` соответствует отдельной теме". Представьте результат в виде столбчатой диаграммы. Подпишите рисунок и дайте названия осям.

# %% [markdown]
# <p class="task" id="4"></p>
#
# 4\. Замените все текстовые смайлики из файла `livejounal/психология.csv` на соответствующие символы юникода. Для поиска смайликов воспользуйтесь регулярными выражениями. Ниже представлен список (не исчерпывающий) примеров возможных смайликов и символ, на который их нужно заменить:
#
# * :=), =-), =-))), ))) и т.д. -> \u263A
# * ;), ;-), ;-)) и т.д. -> \U0001F609
# * :D, :-D, =-D, =-DDD и т.д. -> \U0001F600
# * :=(, :-(, =-(((, (((, ;-( и т.д. -> \U0001F641

# %% [markdown]
# <p class="task" id="5"></p>
#
# 5\. Для каждого поста из файла `livejounal/психология.csv` создайте числовой вектор, в котором содержится следующая информация
#
# * количество абзацев
# * количество предложений
# * количество слов
# * количество смайликов \u263A
# * количество смайликов \U0001F609
# * количество смайликов \U0001F600
# * количество смайликов \U0001F641

# %% [markdown]
# <p class="task" id="6"></p>
#
# 6\. На основе файла `livejounal/психология.csv` выясните, кто из пользователей обладает наиболее широким словарным запасом (т.е. использовал максимальное количество различных слов в своих постах). При подсчете количества слов не учитывайте различные формы одного и того же слова, а также токены, не являющиеся словами (знаки препинания, цифры и т.д.). Выведите на экран имя пользователя и набор используемых им различных слов.
